# %% [markdown]
# # Unsupervised Learning - Emotion Detection
# Apply clustering and dimension reduction algorithms, and see how they may help the Neural Netowrk learner

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import (
    accuracy_score, mean_squared_error, silhouette_score,
    adjusted_rand_score, adjusted_mutual_info_score,
    homogeneity_score, completeness_score, v_measure_score,
)
import time
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, FastICA
import seaborn as sns
from sklearn.mixture import GaussianMixture
from sklearn.random_projection import GaussianRandomProjection
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from keras.models import Sequential
from keras.layers import AveragePooling2D, Conv2D, Dense, Flatten, Reshape
from keras.utils import to_categorical
import random
from scipy import stats
from statsmodels.stats.stattools import durbin_watson

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv('data/emotion-detection/icml_face_data.csv/icml_face_data.csv')
data = data.rename(columns={' Usage': 'Usage', ' pixels': 'pixels'})  # Somehow column names conatin a leading space

# %% [markdown]
# ## Set aside a test set

# %%
train_set = data[data['Usage']=='Training']
test_set = data[data['Usage']=='PrivateTest']
print(len(train_set), 'train istances +', len(test_set), 'test instances')
# Out:
# 28709 train istances + 3589 test instances

# %% [markdown]
# ## Clean data and normalize features

# %%
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_name):
        self.attribute_name = attribute_name
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_name].str.strip('"').str.split(pat=' ', expand=True).values

pipeline = Pipeline([
    ('selector', DataFrameSelector('pixels')),
    ('std_scaler', StandardScaler()),
])

train_X = pipeline.fit_transform(train_set)
train_y = np.array(train_set['emotion'])
test_X = pipeline.transform(test_set)
test_y = np.array(test_set['emotion'])

# %% [markdown]
# ## Re-establish the baseline for neural network learner

# %%
neural_netowrk_hyper_parameters = {
    'compiler': {
        'loss': 'categorical_crossentropy',
        'optimizer': 'adam',
        'metrics': ['accuracy'],
    },
    'epochs': 100,
    'batch_size': 1000,
    'verbose': 1,
}

# %%
def construct_neural_network_model_0():
    # The famous LeNet-5 neural network with the following adaptation:
    # 1. proper reshaping at the beginning to fit desired input shape
    # 2. last layer of units=7 to fit 7-class classification
    # Codes are adapted from https://medium.com/@mgazar/lenet-5-in-9-lines-of-code-using-keras-ac99294c8086
    clf = Sequential()
    clf.add(Dense(units=120, activation='relu', input_shape=(2304,)))
    clf.add(Dense(units=84, activation='relu'))
    clf.add(Dense(units=7, activation='softmax'))
    clf.compile(**neural_netowrk_hyper_parameters['compiler'])
    clf.summary()
    return clf

def plot_learning_curve(training_history):
    plt.figure(random.randint(0, 10000))
    plt.plot(training_history.history['accuracy'])
    plt.plot(training_history.history['val_accuracy'])
    plt.title('Learning curve')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()

def run_neural_netowrk_learner(clf, train_X, train_y, test_X, test_y):
    categorical_train_y = to_categorical(train_y, 7)
    categorical_test_y = to_categorical(test_y, 7)
    training_history = clf.fit(
        train_X, categorical_train_y,
        validation_data=([test_X], [categorical_test_y]),
        epochs=neural_netowrk_hyper_parameters['epochs'],
        batch_size=neural_netowrk_hyper_parameters['batch_size'],
    )
    return training_history
    
clf = construct_neural_network_model_0()
training_history = run_neural_netowrk_learner(clf, train_X, train_y, test_X, test_y)
plot_learning_curve(training_history)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 120)               276600
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 595
# =================================================================
# Total params: 287,359
# Trainable params: 287,359
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - 0s 14ms/step - loss: 1.8218 - accuracy: 0.2986 - val_loss: 1.6980 - val_accuracy: 0.3475
# Epoch 2/100
# 29/29 [==============================] - 0s 7ms/step - loss: 1
100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0733 - accuracy: 0.9860 - val_loss: 4.3650 - val_accuracy: 0.4146
# Epoch 93/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0899 - accuracy: 0.9788 - val_loss: 4.3833 - val_accuracy: 0.4076
# Epoch 94/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0904 - accuracy: 0.9781 - val_loss: 4.3741 - val_accuracy: 0.4124
# Epoch 95/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0881 - accuracy: 0.9805 - val_loss: 4.3971 - val_accuracy: 0.4062
# Epoch 96/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0787 - accuracy: 0.9837 - val_loss: 4.4418 - val_accuracy: 0.4090
# Epoch 97/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0813 - accuracy: 0.9818 - val_loss: 4.4652 - val_accuracy: 0.4043
# Epoch 98/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0682 - accuracy: 0.9869 - val_loss: 4.5024 - val_accuracy: 0.4096
# Epoch 99/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0702 - accuracy: 0.9854 - val_loss: 4.5558 - val_accuracy: 0.4110
# Epoch 100/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0679 - accuracy: 0.9864 - val_loss: 4.5776 - val_accuracy: 0.4085

# %% [markdown]
# ## Part I: Run clustering algorithms

# %%
clustering_algorithm = 'em'
assert clustering_algorithm in {'k_means', 'em'}
n_clusters = 26  # Set to an integer (discovered best n_clusters) or a list of integers (to discover best n_clusters)

# %%
def constuct_clustering_model(clustering_algorithm, n_clusters):
    if clustering_algorithm == 'k_means':
        clustering_model = KMeans(random_state=0, n_clusters=n_clusters)
    elif clustering_algorithm == 'em':
        clustering_model = GaussianMixture(random_state=0, n_components=n_clusters)
    return clustering_model

def run_clustering_algorithm(clustering_algorithm, n_clusters, train_X):
    if isinstance(n_clusters, int):
        clustering_model = constuct_clustering_model(clustering_algorithm, n_clusters)
        start_time = time.time()
        clustering_model.fit(train_X)
        end_time = time.time()
        print('-----------------------------------------------------------------------')
        print('Result for n_clusters: {}'.format(n_clusters))
        print('Time elapsed (in seconds): {}'.format(end_time - start_time))
        print('Silhouette score: {}'.format(silhouette_score(train_X, clustering_model.predict(train_X), metric='euclidean')))
        if clustering_algorithm == 'k_means':
            print('Sum of squared distances of samples to their closest cluster center: {}'
                  .format(clustering_model.inertia_))
        elif clustering_algorithm == 'em':
            print('AIC: {0}, and BIC: {1}'.format(clustering_model.aic(train_X), clustering_model.bic(train_X)))
    elif isinstance(n_clusters, list):
        sses = []
        aics = []
        bics = []
        silhouette_scores = []
        for n in n_clusters:
            clustering_model = constuct_clustering_model(clustering_algorithm, n)
            start_time = time.time()
            clustering_model.fit(train_X)
            end_time = time.time()
            print('-----------------------------------------------------------------------')
            print('Result for n_clusters: {}'.format(n))
            print('Time elapsed (in seconds): {}'.format(end_time - start_time))
            silhouette = silhouette_score(train_X, clustering_model.predict(train_X), metric='euclidean')
            print('Silhouette score: {}'.format(silhouette))
            silhouette_scores.append(silhouette)
            if clustering_algorithm == 'k_means':
                print('Sum of squared distances of samples to their closest cluster center: {}'
                      .format(clustering_model.inertia_))
                sses.append(clustering_model.inertia_)
            elif clustering_algorithm == 'em':
                aic = clustering_model.aic(train_X)
                bic = clustering_model.bic(train_X)
                print('AIC: {0}, and BIC: {1}'.format(aic, bic))
                aics.append(aic)
                bics.append(bic)
        plt.figure(random.randint(0, 10000))
        plt.plot(n_clusters, silhouette_scores)
        plt.title('Silhouette score v.s. k')
        plt.xlabel('k')
        plt.ylabel('Silhouette score')
        plt.show()
        if clustering_algorithm == 'k_means':
            plt.figure(random.randint(0, 10000))
            plt.plot(n_clusters, sses)
            plt.title('Sum of squared distances of samples to their closest cluster center')
            plt.xlabel('k')
            plt.ylabel('Sum Squared Error')
            plt.show()
        elif clustering_algorithm == 'em':
            plt.figure(random.randint(0, 10000))
            plt.plot(n_clusters, aics, label='AIC')
            plt.plot(n_clusters, bics, label='BIC')
            plt.legend(loc='lower right')
            plt.title('AIC or BIC v.s. k')
            plt.xlabel('k')
            plt.ylabel('AIC or BIC')
            plt.show()
    else:
        raise ValueError('Invalid argument n_clusters: {}. Only int or list of int supported!'.format(n_clusters))
    return clustering_model

# %%
def eval_clustering_result(train_y, pred_y):
    print('Adjusted rand score: {}'.format(adjusted_rand_score(train_y, pred_y)))
    print('Adjusted mutual information score: {}'.format(adjusted_mutual_info_score(train_y, pred_y)))
    print('Homogeneity score: {}'.format(homogeneity_score(train_y, pred_y)))
    print('Completeness score: {}'.format(completeness_score(train_y, pred_y)))
    print('V-measure score: {}'.format(v_measure_score(train_y, pred_y)))

# %%
def sample_rows(X, y, num_rows_to_sample):
    num_total_rows = X.shape[0]
    random_indices = np.random.choice(num_total_rows, size=num_rows_to_sample, replace=False)
    return X[random_indices, :], y[random_indices]

# %%
def viz(X, y):
    # Visulize dimensionality reduction result against true or predicted labels in 2D
    if X.shape[1] > 50:
        X = PCA(n_components=50).fit_transform(X)
    if X.shape[0] > 100:
        X, y = sample_rows(X, y, 100)
    embedded_X = TSNE(random_state=0, n_components=2).fit_transform(X)
    df_tsne = pd.DataFrame(embedded_X, columns=['comp1', 'comp2'])
    df_tsne['label'] = y
    sns.lmplot(x='comp1', y='comp2', data=df_tsne, hue='label', fit_reg=False)

# %%
def clustering_all_in_one(clustering_algorithm, n_clusters, train_X, train_y, plot=True):
    # Run clustering algorithm
    clustering_model = run_clustering_algorithm(clustering_algorithm, n_clusters, train_X)
    # Evaluate clustering result against true labels
    pred_y = clustering_model.predict(train_X)
    eval_clustering_result(train_y, pred_y)
    # Visulize clustering result in 2D
    if plot:
        viz(train_X, pred_y)
    return pred_y, clustering_model

clustering_all_in_one(clustering_algorithm, n_clusters, train_X, train_y)
# Out:
# -----------------------------------------------------------------------
# Result for n_clusters: 26
# Time elapsed (in seconds): 323.2320787906647
# Silhouette score: 0.036759050487178764
# AIC: -261073818.4931832, and BIC: 310029451.66947967
# Adjusted rand score: 0.004347838725571984
# Adjusted mutual information score: 0.014754079271702624
# Homogeneity score: 0.02200295477910097
# Completeness score: 0.012297266227495865
# V-measure score: 0.015776935819633242
# (array([17,  3, 15, ..., 10,  1, 11]),
#  GaussianMixture(n_components=26, random_state=0))

# %% [markdown]
# ## Part II: Apply dimensionality reduction algorithms

# %%
dr_algorithm = 'lda'
assert dr_algorithm in {'pca', 'ica', 'random_projection', 'lda'}
n_components = 6  # For random_projection, set to 'auto'

# %%
def construct_dr_model(dr_algorithm, n_components):
    if dr_algorithm == 'pca':
        dr_model = PCA(random_state=0, n_components=n_components)
    elif dr_algorithm == 'ica':
        dr_model = FastICA(random_state=0, n_components=n_components)
    elif dr_algorithm == 'random_projection':
        dr_model = GaussianRandomProjection(random_state=0, n_components=n_components, eps=0.5)
    elif dr_algorithm == 'lda':
        dr_model = LinearDiscriminantAnalysis(n_components=n_components)
    return dr_model

# %%
def dr_all_in_one(dr_algorithm, n_components, train_X, train_y):
    # Apply dimensionality reduction algorithm
    dr_model = construct_dr_model(dr_algorithm, n_components)
    reduced_X = dr_model.fit_transform(train_X, train_y)
    # Evaluate MSE between original data and reconstructed data (if possible)
    if dr_algorithm == 'pca' or dr_algorithm == 'ica':
        reconstructed_X = dr_model.inverse_transform(reduced_X)
        print('MSE between original data and reconstructed data: {}'
              .format(mean_squared_error(train_X, reconstructed_X)))
    return reduced_X, dr_model

if n_components is None:
    if dr_algorithm == 'pca':
        _, dr_model = dr_all_in_one(dr_algorithm, n_components, train_X, train_y)
        # Determine n_components that could keep 95% of the variance
        cumsum = np.cumsum(dr_model.explained_variance_ratio_)
        min_n_components = np.argmax(cumsum >= 0.95) + 1
        print('To keep 95% of the variance, reduced dimension needs to be no smaller than {}'
              .format(min_n_components))
    elif dr_algorithm == 'ica':
        ns = list(range(10, 200, 10))
        avg_kurtosis = []
        min_kurtosis = []
        max_kurtosis = []
        avg_dw = []
        min_dw = []
        max_dw = []
        for n in ns:
            reduced_X, _ = dr_all_in_one(dr_algorithm, n, train_X, train_y)
            kurts = np.absolute(stats.kurtosis(reduced_X, fisher=True))
            avg_kurtosis.append(np.mean(kurts))
            min_kurtosis.append(np.min(kurts))
            max_kurtosis.append(np.max(kurts))
            dws = durbin_watson(reduced_X)
            avg_dw.append(np.mean(dws))
            min_dw.append(np.min(dws))
            max_dw.append(np.max(dws))
        plt.figure(random.randint(0, 10000))
        plt.plot(ns, avg_kurtosis, label='Avg Kurtosis')
        plt.plot(ns, min_kurtosis, label='Min Kurtosis')
        plt.plot(ns, max_kurtosis, label='Max Kurtosis')
        plt.xlabel('n_components')
        plt.ylabel('Kurtosis')
        plt.title('Kurtosis v.s. n_components')
        plt.legend(loc='upper left')
        plt.show()
        plt.figure(random.randint(0, 10000))
        plt.plot(ns, avg_dw, label='Avg Durbin-Watson')
        # plt.plot(ns, min_dw, label='Min Durbin-Watson')
        plt.plot(ns, max_dw, label='Max Durbin-Watson')
        plt.xlabel('n_components')
        plt.ylabel('Durbin-Watson')
        plt.title('Durbin-Watson v.s. n_components')
        plt.legend(loc='upper right')
        plt.show()
    elif dr_algorithm == 'lda':
        ns = list(range(2, 7))
        explained_variance_ratios = []
        for n in ns:
            _, dr_model = dr_all_in_one(dr_algorithm, n, train_X, train_y)
            explained_variance_ratios.append(np.sum(dr_model.explained_variance_ratio_))
        plt.figure(random.randint(0, 10000))
        plt.plot(ns, explained_variance_ratios)
        plt.xlabel('n_components')
        plt.ylabel('Explained variance ratio')
        plt.title('Explained variance ratio v.s. n_components')
        plt.show()
else:
    reduced_X, dr_model = dr_all_in_one(dr_algorithm, n_components, train_X, train_y)
    if dr_algorithm == 'pca':
        plt.plot(dr_model.explained_variance_)
        plt.xlabel('Component')
        plt.ylabel('Eigenvalue (explained_variance)')
    elif dr_algorithm == 'random_projection':
        print('To keep the distortion within eps = 0.5, reduced dimension needs to be no smaller than {}'
              .format(dr_model.n_components_))
    viz(reduced_X, train_y)

# %% [markdown]
# ## Part III: Run clustering algorithm after dimensionality reduction

# %%
# Dimensionality reduction settings
dr_algorithm = 'lda'
assert dr_algorithm in {'pca', 'ica', 'random_projection', 'lda'}
n_components = 6

# Clustering settings
clustering_algorithm = 'em'
assert clustering_algorithm in {'k_means', 'em'}
n_clusters = 7  # Set to an integer (discovered best n_clusters) or a list (to discover best n_clusters)

# %%
if dr_algorithm == 'lda':
    lda_train_X, lda_test_X, lda_train_y, lda_test_y = train_test_split(
        train_X, train_y, test_size=0.2, random_state=0)
    lda_reduced_train_X, dr_model = dr_all_in_one(dr_algorithm, n_components, lda_train_X, lda_train_y)
    lda_reduced_test_X = dr_model.transform(lda_test_X)
    _, clustering_model = clustering_all_in_one(
        clustering_algorithm, n_clusters, lda_reduced_train_X, lda_train_y, plot=False)
    pred_y = clustering_model.predict(lda_reduced_test_X)
    eval_clustering_result(lda_test_y, pred_y)
else:
    reduced_X, _ = dr_all_in_one(dr_algorithm, n_components, train_X, train_y)
    clustering_all_in_one(clustering_algorithm, n_clusters, reduced_X, train_y)
# Out:
# -----------------------------------------------------------------------
# Result for n_clusters: 7
# Time elapsed (in seconds): 0.35282111167907715
# Silhouette score: 0.06406866766336111
# AIC: 409946.56769957626, and BIC: 411514.72136756947
# Adjusted rand score: 0.1202290136016507
# Adjusted mutual information score: 0.14573791693983837
# Homogeneity score: 0.14528010367391067
# Completeness score: 0.14695076494454648
# V-measure score: 0.14611065878860272
# Adjusted rand score: 0.039611179630255455
# Adjusted mutual information score: 0.05033373002746151
# Homogeneity score: 0.05222836830642388
# Completeness score: 0.05173602607971443
# V-measure score: 0.05198103140515862

# %% [markdown]
# ## Part IV: Apply neural network learner after dimensionality reduction

# %%
# Dimensionality reduction settings
dr_algorithm = 'lda'
assert dr_algorithm in {'pca', 'ica', 'random_projection', 'lda'}
n_components = 6

# Neural netowrk learner settings
neural_netowrk_hyper_parameters = {
    'compiler': {
        'loss': 'categorical_crossentropy',
        'optimizer': 'adam',
        'metrics': ['accuracy'],
    },
    'epochs': 100,
    'batch_size': 1000,
    'verbose': 1,
}

# %%
def construct_neural_network_model_1():
    # The famous LeNet-5 neural network with the following adaptation:
    # 1. proper reshaping at the beginning to fit desired input shape
    # 2. last layer of units=7 to fit 7-class classification
    # Codes are adapted from https://medium.com/@mgazar/lenet-5-in-9-lines-of-code-using-keras-ac99294c8086
    clf = Sequential()
    clf.add(Dense(units=120, activation='relu', input_shape=(n_components,)))
    clf.add(Dense(units=84, activation='relu'))
    clf.add(Dense(units=7, activation='softmax'))
    clf.compile(**neural_netowrk_hyper_parameters['compiler'])
    clf.summary()
    return clf

def plot_learning_curve(training_history):
    plt.figure(random.randint(0, 10000))
    plt.plot(training_history.history['accuracy'])
    plt.plot(training_history.history['val_accuracy'])
    plt.title('Learning curve')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()

def run_neural_network_learner(clf, train_X, train_y, test_X, test_y):
    categorical_train_y = to_categorical(train_y, 7)
    categorical_test_y = to_categorical(test_y, 7)
    training_history = clf.fit(
        train_X, categorical_train_y,
        validation_data=([test_X], [categorical_test_y]),
        epochs=neural_netowrk_hyper_parameters['epochs'],
        batch_size=neural_netowrk_hyper_parameters['batch_size'],
    )
    return training_history
    
reduced_train_X, dr_model = dr_all_in_one(dr_algorithm, n_components, train_X, train_y)
reduced_test_X = dr_model.transform(test_X)
clf = construct_neural_network_model_1()
training_history = run_neural_network_learner(clf, reduced_train_X, train_y, reduced_test_X, test_y)
plot_learning_curve(training_history)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 120)               840
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 595
# =================================================================
# Total params: 11,599
# Trainable params: 11,599
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - 0s 4ms/step - loss: 1.6334 - accuracy: 0.4110 - val_loss: 1.7326 - val_accuracy: 0.3472
# Epoch 2/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3821 - accuracy: 0.4874 - val_loss: 1.8135 - val_accuracy: 0.3455
# Epoch 3/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3565 - accuracy: 0.4924 - val_loss: 1.7914 - val_accuracy: 0.3486
# Epoch 4/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3490 - accuracy: 0.4933 - val_loss: 1.7906 - val_accuracy: 0.3438
# Epoch 5/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3456 - accuracy: 0.4932 - val_loss: 1.7844 - val_accuracy: 0.3488
# Epoch 6/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3443 - accuracy: 0.4941 - val_loss: 1.7909 - val_accuracy: 0.3530
# Epoch 7/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3423 - accuracy: 0.4953 - val_loss: 1.7861 - val_accuracy: 0.3483
# Epoch 8/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3406 - accuracy: 0.4942 - val_loss: 1.7821 - val_accuracy: 0.3497
# Epoch 9/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3396 - accuracy: 0.4953 - val_loss: 1.7838 - val_accuracy: 0.3477
# Epoch 10/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3388 - accuracy: 0.4959 - val_loss: 1.7855 - val_accuracy: 0.3508
# Epoch 11/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3392 - accuracy: 0.4964 - val_loss: 1.7832 - val_accuracy: 0.3494
# Epoch 12/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3375 - accuracy: 0.4966 - val_loss: 1.7841 - val_accuracy: 0.3522
# Epoch 13/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3367 - accuracy: 0.4972 - val_loss: 1.7833 - val_accuracy: 0.3491
# Epoch 14/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3370 - accuracy: 0.4964 - val_loss: 1.7822 - val_accuracy: 0.3539
# Epoch 15/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3354 - accuracy: 0.4965 - val_loss: 1.7860 - val_accuracy: 0.3461
# Epoch 16/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3355 - accuracy: 0.4964 - val_loss: 1.7854 - val_accuracy: 0.3514
# Epoch 17/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3356 - accuracy: 0.4965 - val_loss: 1.7869 - val_accuracy: 0.3486
# Epoch 18/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3346 - accuracy: 0.4975 - val_loss: 1.7831 - val_accuracy: 0.3527
# Epoch 19/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3339 - accuracy: 0.4966 - val_loss: 1.7906 - val_accuracy: 0.3505
# Epoch 20/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.
100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3136 - accuracy: 0.5034 - val_loss: 1.8123 - val_accuracy: 0.3488
# Epoch 82/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3144 - accuracy: 0.5033 - val_loss: 1.7990 - val_accuracy: 0.3505
# Epoch 83/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3133 - accuracy: 0.5035 - val_loss: 1.7954 - val_accuracy: 0.3469
# Epoch 84/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3126 - accuracy: 0.5052 - val_loss: 1.8010 - val_accuracy: 0.3516
# Epoch 85/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3117 - accuracy: 0.5042 - val_loss: 1.8046 - val_accuracy: 0.3516
# Epoch 86/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3120 - accuracy: 0.5048 - val_loss: 1.8121 - val_accuracy: 0.3444
# Epoch 87/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3116 - accuracy: 0.5028 - val_loss: 1.8026 - val_accuracy: 0.3483
# Epoch 88/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3119 - accuracy: 0.5039 - val_loss: 1.8095 - val_accuracy: 0.3483
# Epoch 89/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3117 - accuracy: 0.5053 - val_loss: 1.8178 - val_accuracy: 0.3480
# Epoch 90/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3115 - accuracy: 0.5039 - val_loss: 1.8003 - val_accuracy: 0.3424
# Epoch 91/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3112 - accuracy: 0.5048 - val_loss: 1.8042 - val_accuracy: 0.3466
# Epoch 92/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3120 - accuracy: 0.5037 - val_loss: 1.8017 - val_accuracy: 0.3438
# Epoch 93/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3106 - accuracy: 0.5059 - val_loss: 1.8092 - val_accuracy: 0.3452
# Epoch 94/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3098 - accuracy: 0.5047 - val_loss: 1.8008 - val_accuracy: 0.3522
# Epoch 95/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3102 - accuracy: 0.5056 - val_loss: 1.8053 - val_accuracy: 0.3424
# Epoch 96/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3095 - accuracy: 0.5060 - val_loss: 1.8046 - val_accuracy: 0.3455
# Epoch 97/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3085 - accuracy: 0.5069 - val_loss: 1.8058 - val_accuracy: 0.3494
# Epoch 98/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3092 - accuracy: 0.5050 - val_loss: 1.8040 - val_accuracy: 0.3449
# Epoch 99/100
# 29/29 [==============================] - 0s 1ms/step - loss: 1.3091 - accuracy: 0.5056 - val_loss: 1.8140 - val_accuracy: 0.3488
# Epoch 100/100
# 29/29 [==============================] - 0s 2ms/step - loss: 1.3079 - accuracy: 0.5050 - val_loss: 1.8023 - val_accuracy: 0.3410

# %% [markdown]
# ## Part V: Apply neural network learner after clustering

# %%
# Dimensionality reduction settings
dr_algorithm = 'lda'
assert dr_algorithm in {'pca', 'ica', 'random_projection', 'lda'}
n_components = 6

# Clustering settings
clustering_algorithm = 'em'
assert clustering_algorithm in {'k_means', 'em'}
n_clusters = 7  # Set to an integer (discovered best n_clusters) or a list (to discover best n_clusters)

# Neural netowrk learner settings
neural_netowrk_hyper_parameters = {
    'compiler': {
        'loss': 'categorical_crossentropy',
        'optimizer': 'adam',
        'metrics': ['accuracy'],
    },
    'epochs': 100,
    'batch_size': 1000,
    'verbose': 1,
}

# %%
def construct_neural_network_model_2():
    # The famous LeNet-5 neural network with the following adaptation:
    # 1. proper reshaping at the beginning to fit desired input shape
    # 2. last layer of units=7 to fit 7-class classification
    # Codes are adapted from https://medium.com/@mgazar/lenet-5-in-9-lines-of-code-using-keras-ac99294c8086
    clf = Sequential()
    clf.add(Dense(units=120, activation='relu', input_shape=(2304 + n_clusters,)))
    clf.add(Dense(units=84, activation='relu'))
    clf.add(Dense(units=7, activation='softmax'))
    clf.compile(**neural_netowrk_hyper_parameters['compiler'])
    clf.summary()
    return clf

reduced_X, dr_model = dr_all_in_one(dr_algorithm, n_components, train_X, train_y)
train_cluster_labels, clustering_model = clustering_all_in_one(clustering_algorithm, n_clusters, reduced_X, train_y)
test_cluster_labels = clustering_model.predict(dr_model.transform(test_X))
# train_cluster_labels, clustering_model = clustering_all_in_one(clustering_algorithm, n_clusters, train_X, train_y)
# test_cluster_labels = clustering_model.predict(test_X)
one_hot = OneHotEncoder()
one_hot_train_cluster_labels = one_hot.fit_transform(train_cluster_labels.reshape(-1, 1)).todense()
one_hot_test_cluster_labels = one_hot.transform(test_cluster_labels.reshape(-1, 1)).todense()
new_train_X = np.hstack((train_X, one_hot_train_cluster_labels))  # one_hot_train_cluster_labels
new_test_X = np.hstack((test_X, one_hot_test_cluster_labels))  # one_hot_test_cluster_labels
clf = construct_neural_network_model_2()
training_history = run_neural_network_learner(
    clf, new_train_X, train_y, new_test_X, test_y)
plot_learning_curve(training_history)
# Out:
# -----------------------------------------------------------------------
# Result for n_clusters: 7
# Time elapsed (in seconds): 0.4326040744781494
# Silhouette score: 0.07267737380066183
# AIC: 509078.12952144316, and BIC: 510689.7978800238
# Adjusted rand score: 0.10160603966393814
# Adjusted mutual information score: 0.133988394711491
# Homogeneity score: 0.13210497595469084
# Completeness score: 0.13655660944720596
# V-measure score: 0.13429391165462756
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 120)               277440
# _________________________________________________________________
# dense_7 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 595
# =================================================================
# Total params: 288,199
# Trainable params: 288,199
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - 0s 11ms/step - loss: 1.8037 - accuracy: 0.3019 - val_loss: 1.6680 - val_accuracy: 0.3553
# Epoch 2/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.5877 - accuracy: 0.3899 - val_loss: 1.6076 - val_accuracy: 0.3867
# Epoch 3/100
# 29/29 [==============================] - 0s 7ms/step - loss: 1.5068 - accuracy: 0.4257 - val_loss: 1.5899 - val_accuracy: 0.3965
# Epoch 4/100
# 29/29 [==============================] - 0s 7ms/step - loss: 1.4427 - accuracy: 0.4550 - val_loss: 1.5677 - val_accuracy: 0.3993
# Epoch 5/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.3826 - accuracy: 0.4831 - val_loss: 1.5474 - val_accuracy: 0.4126
# Epoch 6/100
# 29/29 [==============================] - 0s 7ms/step - loss: 1.3387 - accuracy: 0.4992 - val_loss: 1.5543 - val_accuracy: 0.4168
# Epoch 7/100
# 29/29 [==============================] - 0s 8ms/step - loss: 1.2893 - accuracy: 0.5215 - val_loss: 1.5691 - val_accuracy: 0.3998
# Epoch 8/100
# 29/29 [==============================] - 0s 7ms/step - loss: 1.2438 - accuracy: 0.5402 - val_loss: 1.5700 - val_accuracy: 0.4160
# Epoch 9/100
# 29/29 [==============================] - 0s 8ms/step - loss: 1.2074 - accuracy: 0.5529 - val_loss: 1.5644 - val_accuracy: 0.4149
# Epoch 10/100
# 29/29 [==============================] - 0s 7ms/step - loss: 1.1622 - accuracy: 0.5738 - val_loss: 1.5903 - val_accuracy: 0.4168
# Epoch 11/100
# 29/29 [==============================] - 0s 8ms/step - loss: 1.1331 - accuracy: 0.5873 - val_loss: 1.5892 - val_accuracy: 0.4202
# Epoch 12/100
# 29/29 [==============================] - 0s 7ms/step - loss: 1.0900 - accuracy: 0.6023 - val_loss: 1.6107 - val_accuracy: 0.4249
# Epoch 13/100
# 29/29 [==============================] - 0s 8ms/step - loss: 1.0531 - accuracy: 0.6180 - val_loss: 1.6198 - val_accuracy: 0.4221
# Epoch 14/100
# 29/29 [==============================] - 0s 8ms/step - loss: 1.0191 - accuracy: 0.6303 - val_loss: 1.6481 - val_accuracy: 0.4188
# Epoch 15/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.9892 - accuracy: 0.6450 - val_loss: 1.6968 - val_accuracy: 0.4090
# Epoch 16/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.9569 - accuracy: 0.6566 - val_loss: 1.6912 - val_accuracy: 0.4271
# Epoch 17/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.9255 - accuracy: 0.6710 - val_loss: 1.7342 - val_accuracy: 0.4126
# Epoch 18/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.8990 - accuracy: 0.6811 - val_loss: 1.7479 - val_accuracy: 0.4138
# Epoch 19/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.8744 - accuracy: 0.6878 - val_loss: 1.7453 - val_accuracy: 0.4196
# Epoch 20/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.8296 - accuracy: 0.7069 - val_loss: 1.7820 - val_accuracy: 0.4191
# Epoch 21/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.8004 - accuracy: 0.7180 - val_loss: 1.8172 - val_accuracy: 0.4246
# Epoch 22/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.7789 - accuracy: 0.7252 - val_loss: 1.8621 - val_accuracy: 0.4196
# Epoch 23/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7669 - accuracy: 0.7330 - val_loss: 1.8817 - val_accuracy: 0.4221
# Epoch 24/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.7266 - accuracy: 0.7470 - val_loss: 1.9205 - val_accuracy: 0.4140
# Epoch 25/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.7109 - accuracy: 0.7506 - val_loss: 1.9543 - val_accuracy: 0.4160
# Epoch 26/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6852 - accuracy: 0.7628 - val_loss: 1.9951 - val_accuracy: 0.4232
# Epoch 27/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.6695 - accuracy: 0.7688 - val_loss: 2.0258 - val_accuracy: 0.4135
# Epoch 28/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.6288 - accuracy: 0.7876 - val_loss: 2.0555 - val_accuracy: 0.4046
# Epoch 29/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.6057 - accuracy: 0.7938 - val_loss: 2.0769 - val_accuracy: 0.4179
# Epoch 30/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.5891 - accuracy: 0.8046 - val_loss: 2.1070 - val_accuracy: 0.4210
# Epoch 31/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5495 - accuracy: 0.8212 - val_loss: 2.1193 - val_accuracy: 0.4177
# Epoch 32/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.5373 - accuracy: 0.8237 - val_loss: 2.1666 - val_accuracy: 0.4185
# Epoch 33/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.5247 - accuracy: 0.8258 - val_loss: 2.2462 - val_accuracy: 0.4202
# Epoch 34/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.5107 - accuracy: 0.8309 - val_loss: 2.2447 - val_accuracy: 0.4235
# Epoch 35/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.4909 - accuracy: 0.8409 - val_loss: 2.3057 - val_accuracy: 0.4160
# Epoch 36/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.4643 - accuracy: 0.8497 - val_loss: 2.3353 - val_accuracy: 0.4230
# Epoch 37/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4536 - accuracy: 0.8544 - val_loss: 2.3765 - val_accuracy: 0.4269
# Epoch 38/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4362 - accuracy: 0.8592 - val_loss: 2.4224 - val_accuracy: 0.4177
# Epoch 39/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.4363 - accuracy: 0.8595 - val_loss: 2.4452 - val_accuracy: 0.4113
# Epoch 40/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.4129 - accuracy: 0.8696 - val_loss: 2.4704 - val_accuracy: 0.4171
# Epoch 41/100
# 29/29 [==============================] - 0s 7ms/step - loss: 0.3977 - accuracy: 0.8759 - val_loss: 2.5350 - val_accuracy: 0.4205
# Epoch 42/100
# 29/29 [==============================] - 0s 8ms/step - loss: 0.